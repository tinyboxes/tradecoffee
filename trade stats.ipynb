# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
trade = pd.read_csv('~/Desktop/tradecoffee/data/tradecoffee.csv', index_col = 0)

# %%
trade.iloc[:10]
# Out:
#                            name      roaster  \
# 0                      71 House  Irving Farm
# 1        Costa Rica Santa Maria  Huckleberry
# 2      Ad Astra Signature Blend         PT's
# 3          Inkwell, House Blend       Quills
# 4                        Ruby's         DOMA
# 5                          Lyon   La Colombe
# 6                       Corsica   La Colombe
# 7                    Caffe Luna   Caffe Vita
# 8  Ethiopia, Semalo Pride Honey      Maquina
# 9                       Mixtape      Dogwood
#
#                                           descriptor   price  weight  \
# 0  This signature House Blend was crafted as the ...  $14.75  12 oz.
# 1  Smooth, lush, and clean, with soft apple acidi...  $17.00  12 oz.
# 2  If your coffee substitutes as breakfast, this ...  $17.50  12 oz.
# 3  Finally, a crowd-pleaser with some depth. This...  $15.00  12 oz.
# 4  Bold and intricately spiced, full of chocolate...  $16.00  12 oz.
# ...

# %%
trade.dtypes
# Out:
# name              object
# roaster           object
# descriptor        object
# price             object
# weight            object
# location          object
# roasternotes      object
# blend_single      object
# roastlevel        object
# classification    object
# flavornotes       object
# extra             object
# dtype: object

# %%
for i in range(len(trade)):
    trade.price[i] = trade.price[i].replace('$', '').replace('.', '')

# %%
trade.price = trade.price.astype(float)

# %%
type(trade.price)
# Out:
# pandas.core.series.Series

# %%
trade.dtypes
# Out:
# name               object
# roaster            object
# descriptor         object
# price             float64
# weight             object
# location           object
# roasternotes       object
# blend_single       object
# roastlevel         object
# classification     object
# flavornotes        object
# extra              object
# dtype: object

# %%
trade.to_csv('tradecoffe.1.csv')

# %%
import re

# %%
y = trade['weight']
y[0]
# Out:
# '12 oz.'

# %%
oz = trade[trade['weight'] == '12 oz.']

# %%
oz.columns
# Out:
# Index(['name', 'roaster', 'descriptor', 'price', 'weight', 'location',
#        'roasternotes', 'blend_single', 'roastlevel', 'classification',
#        'flavornotes', 'extra'],
#       dtype='object')

# %%
oz
# Out:
#                                   name         roaster  \
# 0                             71 House     Irving Farm
# 1               Costa Rica Santa Maria     Huckleberry
# 2             Ad Astra Signature Blend            PT's
# 3                 Inkwell, House Blend          Quills
# 4                               Ruby's            DOMA
# 5                                 Lyon      La Colombe
# 6                              Corsica      La Colombe
# 7                           Caffe Luna      Caffe Vita
# 8         Ethiopia, Semalo Pride Honey         Maquina
# 9                              Mixtape         Dogwood
# 11                         Hair Bender       Stumptown
# 12                    Southern Weather            Onyx
# 13          Nicaragua Finca La Amistad         Panther
# 14                  Colombia El Jigual     Irving Farm
# 15   Ethiopia Bensa Shantawene Natural            Onyx
# 16      Costa Rica Perla Negra Natural            Dune
# ...

# %%
oz['weight'] = oz['weight'].str.split(' ').str[0]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
oz['weight'] = oz['weight'].astype(float)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
oz.dtypes
# Out:
# name               object
# roaster            object
# descriptor         object
# price             float64
# weight            float64
# location           object
# roasternotes       object
# blend_single       object
# roastlevel         object
# classification     object
# flavornotes        object
# extra              object
# dtype: object

# %%
ounces = trade[(trade['weight'] == '12 oz.')|(trade['weight'] == '18 oz.')|(trade['weight'] == '10 oz.')|(trade['weight'] == '16 oz.')|(trade['weight'] == '8 oz.')]

# %%
grams = trade[(trade['weight'] == '300 g.')]

# %%
ounces['weight'] = ounces['weight'].str.split(' ').str[0]
ounces['weight'] = ounces['weight'].astype(float)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
grams['weight'] = grams['weight'].str.split(' ').str[0]
grams['weight'] = grams['weight'].astype(float)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ounces['weight in g'] = ounces['weight']/0.03527396195
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
grams['weight in oz'] = grams['weight']*0.03527396195
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ounces['weight in oz'] = ounces['weight']
ounces
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                   name         roaster  \
# 0                             71 House     Irving Farm
# 1               Costa Rica Santa Maria     Huckleberry
# 2             Ad Astra Signature Blend            PT's
# 3                 Inkwell, House Blend          Quills
# 4                               Ruby's            DOMA
# 5                                 Lyon      La Colombe
# 6                              Corsica      La Colombe
# 7                           Caffe Luna      Caffe Vita
# 8         Ethiopia, Semalo Pride Honey         Maquina
# ...

# %%
grams['weight in g'] = grams['weight']
grams
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                       name roaster  \
# 30        Ethiopia Bokasso  Boxcar
# 73         Stella Espresso  Boxcar
# 132         Decaf Colombia  Boxcar
# 265          Cherry Picker  Boxcar
# 352       No.7 House Blend  Boxcar
# 411  Guatemala San Antonio  Boxcar
#
#                                             descriptor   price  weight  \
# 30   Delicate but lingering, this washed Ethiopian ...  1600.0   300.0
# 73   A workhorse for your work (or play) day. Clean...  1275.0   300.0
# 132  Character is everything—and here, in this deca...  1225.0   300.0
# ...

# %%
joined = pd.concat([ounces, grams])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
joined = joined.sort_index(axis=0)

# %%
joined = joined[['name', 'roaster', 'descriptor', 'price', 'weight', 'weight in g', 'weight in oz', 'location',
       'roasternotes', 'blend_single', 'roastlevel', 'classification',
       'flavornotes', 'extra']]

# %%
joined
# Out:
#                                   name         roaster  \
# 0                             71 House     Irving Farm
# 1               Costa Rica Santa Maria     Huckleberry
# 2             Ad Astra Signature Blend            PT's
# 3                 Inkwell, House Blend          Quills
# 4                               Ruby's            DOMA
# 5                                 Lyon      La Colombe
# 6                              Corsica      La Colombe
# 7                           Caffe Luna      Caffe Vita
# 8         Ethiopia, Semalo Pride Honey         Maquina
# 9                              Mixtape         Dogwood
# 10      Gesha Village 2017 Dry Process       Passenger
# 11                         Hair Bender       Stumptown
# 12                    Southern Weather            Onyx
# 13          Nicaragua Finca La Amistad         Panther
# 14                  Colombia El Jigual     Irving Farm
# 15   Ethiopia Bensa Shantawene Natural            Onyx
# ...

# %%
joined.to_csv('joined.csv')

# %%
joined['price'] = joined['price']/10

# %%
joined.to_
# Out:
#                                   name         roaster  \
# 0                             71 House     Irving Farm
# 1               Costa Rica Santa Maria     Huckleberry
# 2             Ad Astra Signature Blend            PT's
# 3                 Inkwell, House Blend          Quills
# 4                               Ruby's            DOMA
# 5                                 Lyon      La Colombe
# 6                              Corsica      La Colombe
# 7                           Caffe Luna      Caffe Vita
# 8         Ethiopia, Semalo Pride Honey         Maquina
# 9                              Mixtape         Dogwood
# 10      Gesha Village 2017 Dry Process       Passenger
# 11                         Hair Bender       Stumptown
# 12                    Southern Weather            Onyx
# 13          Nicaragua Finca La Amistad         Panther
# 14                  Colombia El Jigual     Irving Farm
# 15   Ethiopia Bensa Shantawene Natural            Onyx
# ...
