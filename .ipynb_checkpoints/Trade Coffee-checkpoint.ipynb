# %%
import pandas as pd
import numpy as np

# %%
trade = pd.read_csv('tradecoffee.csv', index_col=0)

# %%
trade.shape
# Out:
# (470, 12)

# %%
trade
# Out:
#                                   name         roaster  \
# 0                             71 House     Irving Farm
# 1               Costa Rica Santa Maria     Huckleberry
# 2             Ad Astra Signature Blend            PT's
# 3                 Inkwell, House Blend          Quills
# 4                               Ruby's            DOMA
# 5                                 Lyon      La Colombe
# 6                              Corsica      La Colombe
# 7                           Caffe Luna      Caffe Vita
# 8         Ethiopia, Semalo Pride Honey         Maquina
# 9                              Mixtape         Dogwood
# 10      Gesha Village 2017 Dry Process       Passenger
# 11                         Hair Bender       Stumptown
# 12                    Southern Weather            Onyx
# 13          Nicaragua Finca La Amistad         Panther
# 14                  Colombia El Jigual     Irving Farm
# 15   Ethiopia Bensa Shantawene Natural            Onyx
# ...

# %%
extra = trade[['name', 'extra']]

# %%
extra.shape
# Out:
# (470, 2)

# %%
test = extra.iloc[30:40]

# %%
print(test)
# Out:
#                 name                                              extra
# 30  Ethiopia Bokasso  ['Process', 'Washed', 'Sub Region', 'Sidama', ...
# 31       Oktoberfest         ['Process', 'Washed', 'Elevation', '1750']
# 32          Darkness       ['Process', 'Washed', 'Varietal', 'Bourbon']
# 33    Kenya Gaturiri  ['Process', 'Washed', 'Sub Region', 'Central K...
# 34           Bauhaus       ['Process', 'Washed', 'Varietal', 'Arabica']
# 35   Party, Ethiopia  ['Process', 'Natural/Dry Processed', 'Sub Regi...
# 36        Zip Zinger  ['Process', 'Washed, Natural/Dry Processed', '...
# 37     Ethiopia Ardi  ['Process', 'Natural/Dry Processed', 'Sub Regi...
# 38        Costa Rica  ['Process', 'Washed', 'Sub Region', 'West Vall...
# 39     Monarch Blend  ['Process', 'Washed', 'Varietal', 'Caturra, Et...

# %%
type(test)
# Out:
# pandas.core.frame.DataFrame

# %%
test.columns
# Out:
# Index(['name', 'extra'], dtype='object')

# %%
extra['extra'] = extra['extra'].map(lambda x: x.lstrip('[').rstrip(']'))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
extra.shape
# Out:
# (470, 2)

# %%
extra
# Out:
#                                   name  \
# 0                             71 House
# 1               Costa Rica Santa Maria
# 2             Ad Astra Signature Blend
# 3                 Inkwell, House Blend
# 4                               Ruby's
# 5                                 Lyon
# 6                              Corsica
# 7                           Caffe Luna
# 8         Ethiopia, Semalo Pride Honey
# 9                              Mixtape
# 10      Gesha Village 2017 Dry Process
# 11                         Hair Bender
# 12                    Southern Weather
# 13          Nicaragua Finca La Amistad
# 14                  Colombia El Jigual
# 15   Ethiopia Bensa Shantawene Natural
# 16      Costa Rica Perla Negra Natural
# 17                              Gotham
# 18          Black Cat Classic Espresso
# 19                        French Roast
# 20                              Brasil
# 21           Le Corbusier French Roast
# 22              Flying Monkey Espresso
# ...

# %%
extra['extra'] = extra['extra'].map(lambda x: x.replace(',', '').replace('\'', ''))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
extra
# Out:
#                                   name  \
# 0                             71 House
# 1               Costa Rica Santa Maria
# 2             Ad Astra Signature Blend
# 3                 Inkwell, House Blend
# 4                               Ruby's
# 5                                 Lyon
# 6                              Corsica
# 7                           Caffe Luna
# 8         Ethiopia, Semalo Pride Honey
# 9                              Mixtape
# 10      Gesha Village 2017 Dry Process
# 11                         Hair Bender
# 12                    Southern Weather
# 13          Nicaragua Finca La Amistad
# 14                  Colombia El Jigual
# 15   Ethiopia Bensa Shantawene Natural
# 16      Costa Rica Perla Negra Natural
# 17                              Gotham
# 18          Black Cat Classic Espresso
# 19                        French Roast
# 20                              Brasil
# 21           Le Corbusier French Roast
# 22              Flying Monkey Espresso
# ...

# %%
keywords = ['Sub Region', 'Process', 'Harvest Time', 'Varietal', 'Elevation', 'Producer']

# %%
import re
keys = re.compile("|".join(keywords))

# %%
keys
# Out:
# re.compile(r'Sub Region|Process|Harvest Time|Varietal|Elevation|Producer',
# re.UNICODE)

# %%
extra.to_csv('extra.csv', index=0)
