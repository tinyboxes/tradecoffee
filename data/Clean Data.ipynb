# %%
import pandas as pd
import numpy as np
import re

# %%
pp = pd.read_csv('~/Desktop/for_cleaning/pro_prod.csv', index_col=0)
ps = pd.read_csv('~/Desktop/for_cleaning/pro_sub.csv', index_col=0)

# %%
print(pp.shape)
print(ps.shape)
# Out:
# (107, 3)
# (7, 3)
# (319, 3)

# %%
pv.index
# Out:
# Int64Index([307, 308, 309, 310, 311, 312, 313, 314, 315, 316,
#             ...
#             459, 460,  32,  33,  34,  35,  36,  37,  38,  39],
#            dtype='int64', length=107)

# %%
ps['extra'] = ps['extra'].str.split('\s')

# %%
ps[''][:28] = ps['extra'][:28].str[0:4]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ps['varietal'] = ''

# %%
ps['sub region'].iloc[10] = ps.extra.iloc[10][3:6]
ps['producer'].iloc[10] = ps.extra.iloc[10][6:9]
ps['harvest time'].iloc[10] = ps.extra.iloc[10][9:11]
ps['elevation'].iloc[10] = ps.extra.iloc[10][11:]
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
ps['harvest time'] = ''

# %%
ps.iloc[10]
# Out:
# index                                                         218
# name                                                      Afrique
# extra           [Process, Washed, Natural/Dry, Processed, Vari...
# process                 [Process, Washed, Natural/Dry, Processed]
# sub region                         [Processed, Varietal, Arabica]
# producer                                                       []
# varietal
# elevation                                                      []
# harvest time                                                   []
# Name: 406, dtype: object

# %%
ps
# Out:
#      index                                  name  \
# 396     96                         Espresso Novo
# 397     28                         Buffalo Blend
# 398    265                         Cherry Picker
# 399     65                     Blue Orchid Blend
# 400    111                           Penrose v18
# 401    346                    Phantom Limb Blend
# 402    311          Organic Icebreaker Cold Brew
# 403    357                      Organic Infrared
# 404    226                              Fishtown
# 405    231                               Bourbon
# 406    218                               Afrique
# 407    382                    Decaf Bitches Brew
# 408     78                        Sound & Vision
# 409    448                            Blackstrap
# 410    451                          Bistro Blend
# 411    462                          Bistro Blend
# 412    350                            Queen City
# 413     50                      Organic Espresso
# ...
